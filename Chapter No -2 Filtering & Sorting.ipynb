# %% [markdown]
# # Terminology Alert
# * Rows - Observations/Records/Datapoints
# * Columns - Features/Parameters

# %%
import pandas as pd

# %%
football_stats = pd.read_csv('Euro_2012_stats_TEAM.csv')
football_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0              0              0                     0  ...          13
# 1              0              0                     0  ...           9
# 2              1              0                     0  ...          10
# 3              0              0                     0  ...          22
# 4              1              0                     0  ...           6
# 5              2              1                     0  ...          10
# 6              1              1                     1  ...          13
# 7              2              0                     0  ...          20
# 8              2              0                     0  ...          12
# 9              0              0                     0  ...           6
# 10             6              0                     0  ...          10
# 11             0              0                     0  ...          17
# 12             2              0                     0  ...          10
# 13             0              1                     0  ...          15
# 14             3              0                     0  ...           8
# 15             0              0                     0  ...          13
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 0                  81.3%         41             62         2             9
# 1                  60.1%         53             73         8             7
# 2                  66.7%         25             38         8             4
# 3                  88.1%         43             45         6             5
# 4                  54.6%         36             51         5             6
# 5                  62.6%         63             49        12             4
# 6                  65.1%         67             48        12             9
# 7                  74.1%        101             89        16            16
# 8                  70.6%         35             30         3             5
# 9                  66.7%         48             56         3             7
# 10                 71.5%         73             90        10            12
# 11                 65.4%         43             51        11             6
# 12                 77.0%         34             43         4             6
# 13                 93.8%        102             83        19            11
# 14                 61.6%         35             51         7             7
# 15                 76.5%         48             31         4             5
#
#     Red Cards  Subs on  Subs off  Players Used
# 0           0        9         9            16
# 1           0       11        11            19
# 2           0        7         7            15
# 3           0       11        11            16
# 4           0       11        11            19
# 5           0       15        15            17
# 6           1       12        12            20
# 7           0       18        18            19
# 8           0        7         7            15
# 9           1        7         7            17
# 10          0       14        14            16
# 11          1       10        10            17
# 12          0        7         7            16
# 13          0       17        17            18
# 14          0        9         9            18
# 15          0        9         9            18
#
# [16 rows x 35 columns]

# %% [markdown]
# ### 2.1 Display first 5 observations of first 5 columns

# %%
football_stats.iloc[0:5,0:5]  ## Index Locator
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%

# %%
football_stats.iloc[:5,:5]  ## default index locator is 0
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%

# %% [markdown]
# ### 2.2 Display first 5 observations of Team And Shooting Accuracy

# %%
football_stats.iloc[:5,[0,4]]
# Out:
#              Team Shooting Accuracy
# 0         Croatia             51.9%
# 1  Czech Republic             41.9%
# 2         Denmark             50.0%
# 3         England             50.0%
# 4          France             37.9%

# %%
football_stats.loc[:5,['Team','Shooting Accuracy']]
# Out:
#              Team Shooting Accuracy
# 0         Croatia             51.9%
# 1  Czech Republic             41.9%
# 2         Denmark             50.0%
# 3         England             50.0%
# 4          France             37.9%
# 5         Germany             47.8%

# %%
football_stats.iloc[[0,3,4],[0,4]]
# Out:
#       Team Shooting Accuracy
# 0  Croatia             51.9%
# 3  England             50.0%
# 4   France             37.9%

# %% [markdown]
# ### 2.3 Take all observations of Team, Shooting Accuracy, Red Cards and Yellow Cards

# %%
football_stats.loc[:,['Team','Shooting Accuracy','Red Cards','Yellow Cards']]
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 0               Croatia             51.9%          0             9
# 1        Czech Republic             41.9%          0             7
# 2               Denmark             50.0%          0             4
# 3               England             50.0%          0             5
# 4                France             37.9%          0             6
# 5               Germany             47.8%          0             4
# 6                Greece             30.7%          1             9
# 7                 Italy             43.0%          0            16
# 8           Netherlands             25.0%          0             5
# 9                Poland             39.4%          1             7
# 10             Portugal             34.3%          0            12
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 13                Spain             55.9%          0            11
# 14               Sweden             47.2%          0             7
# 15              Ukraine             21.2%          0             5

# %%
# same as above
filtered_data = football_stats[['Team','Shooting Accuracy','Red Cards','Yellow Cards']]
filtered_data
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 0               Croatia             51.9%          0             9
# 1        Czech Republic             41.9%          0             7
# 2               Denmark             50.0%          0             4
# 3               England             50.0%          0             5
# 4                France             37.9%          0             6
# 5               Germany             47.8%          0             4
# 6                Greece             30.7%          1             9
# 7                 Italy             43.0%          0            16
# 8           Netherlands             25.0%          0             5
# 9                Poland             39.4%          1             7
# 10             Portugal             34.3%          0            12
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 13                Spain             55.9%          0            11
# 14               Sweden             47.2%          0             7
# 15              Ukraine             21.2%          0             5

# %% [markdown]
# ### 2.4 Display the team which got more number of Yellow Cards

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
filtered_data.sort_values(by= 'Yellow Cards',ascending=False,inplace=True)
filtered_data
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 7                 Italy             43.0%          0            16
# 10             Portugal             34.3%          0            12
# 13                Spain             55.9%          0            11
# 0               Croatia             51.9%          0             9
# 6                Greece             30.7%          1             9
# 1        Czech Republic             41.9%          0             7
# 9                Poland             39.4%          1             7
# 14               Sweden             47.2%          0             7
# 4                France             37.9%          0             6
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 3               England             50.0%          0             5
# 8           Netherlands             25.0%          0             5
# 15              Ukraine             21.2%          0             5
# 2               Denmark             50.0%          0             4
# 5               Germany             47.8%          0             4

# %% [markdown]
# ### 2.5 Display the teams that got Yellow Cards more than 7 and Red Cards 1

# %%
## filtered_data[(filtered_data['Yellow Cards'] > 7) & (filtered_data['Red Cards'] == 1)]

# %%
filtered_data[(filtered_data['Yellow Cards'] > 7) | (filtered_data['Red Cards'] == 1)]
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 7                 Italy             43.0%          0            16
# 10             Portugal             34.3%          0            12
# 13                Spain             55.9%          0            11
# 0               Croatia             51.9%          0             9
# 6                Greece             30.7%          1             9
# 9                Poland             39.4%          1             7
# 11  Republic of Ireland             36.8%          1             6

# %%
football_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0              0              0                     0  ...          13
# 1              0              0                     0  ...           9
# 2              1              0                     0  ...          10
# 3              0              0                     0  ...          22
# 4              1              0                     0  ...           6
# 5              2              1                     0  ...          10
# 6              1              1                     1  ...          13
# 7              2              0                     0  ...          20
# 8              2              0                     0  ...          12
# 9              0              0                     0  ...           6
# 10             6              0                     0  ...          10
# 11             0              0                     0  ...          17
# 12             2              0                     0  ...          10
# 13             0              1                     0  ...          15
# 14             3              0                     0  ...           8
# 15             0              0                     0  ...          13
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 0                  81.3%         41             62         2             9
# 1                  60.1%         53             73         8             7
# 2                  66.7%         25             38         8             4
# 3                  88.1%         43             45         6             5
# 4                  54.6%         36             51         5             6
# 5                  62.6%         63             49        12             4
# 6                  65.1%         67             48        12             9
# 7                  74.1%        101             89        16            16
# 8                  70.6%         35             30         3             5
# 9                  66.7%         48             56         3             7
# 10                 71.5%         73             90        10            12
# 11                 65.4%         43             51        11             6
# 12                 77.0%         34             43         4             6
# 13                 93.8%        102             83        19            11
# 14                 61.6%         35             51         7             7
# 15                 76.5%         48             31         4             5
#
#     Red Cards  Subs on  Subs off  Players Used
# 0           0        9         9            16
# 1           0       11        11            19
# 2           0        7         7            15
# 3           0       11        11            16
# 4           0       11        11            19
# 5           0       15        15            17
# 6           1       12        12            20
# 7           0       18        18            19
# 8           0        7         7            15
# 9           1        7         7            17
# 10          0       14        14            16
# 11          1       10        10            17
# 12          0        7         7            16
# 13          0       17        17            18
# 14          0        9         9            18
# 15          0        9         9            18
#
# [16 rows x 35 columns]

# %%
football_stats.query('Goals > 4')
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3    England      5               11                18             50.0%
# 5    Germany     10               32                32             47.8%
# 6     Greece      5                8                18             30.7%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 12    Russia      5                9                31             22.5%
# 13     Spain     12               42                33             55.9%
# 14    Sweden      5               17                19             47.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 5             15.6%                          80             2              1
# 6             19.2%                          32             1              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 12            12.5%                          59             2              0
# 13            16.0%                         100             0              1
# 14            13.8%                          39             3              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 3                      0  ...          22                 88.1%         43
# 5                      0  ...          10                 62.6%         63
# 6                      1  ...          13                 65.1%         67
# 7                      0  ...          20                 74.1%        101
# 10                     0  ...          10                 71.5%         73
# 12                     0  ...          10                 77.0%         34
# 13                     0  ...          15                 93.8%        102
# 14                     0  ...           8                 61.6%         35
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 3              45         6             5          0       11        11
# 5              49        12             4          0       15        15
# 6              48        12             9          1       12        12
# 7              89        16            16          0       18        18
# 10             90        10            12          0       14        14
# 12             43         4             6          0        7         7
# 13             83        19            11          0       17        17
# 14             51         7             7          0        9         9
#
#     Players Used
# 3             16
# 5             17
# 6             20
# 7             19
# 10            16
# 12            16
# 13            18
# 14            18
#
# [8 rows x 35 columns]

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Red Cards  Yellow Cards
# 0               Croatia             51.9%          0             9
# 1        Czech Republic             41.9%          0             7
# 2               Denmark             50.0%          0             4
# 3               England             50.0%          0             5
# 4                France             37.9%          0             6
# 5               Germany             47.8%          0             4
# 6                Greece             30.7%          1             9
# 7                 Italy             43.0%          0            16
# 8           Netherlands             25.0%          0             5
# 9                Poland             39.4%          1             7
# 10             Portugal             34.3%          0            12
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 13                Spain             55.9%          0            11
# 14               Sweden             47.2%          0             7
# 15              Ukraine             21.2%          0             5

# %%
filtered_data.columns = [column.replace(" ","_") for column in filtered_data.columns]
filtered_data
# Out:
#                    Team Shooting_Accuracy  Red_Cards  Yellow_Cards
# 0               Croatia             51.9%          0             9
# 1        Czech Republic             41.9%          0             7
# 2               Denmark             50.0%          0             4
# 3               England             50.0%          0             5
# 4                France             37.9%          0             6
# 5               Germany             47.8%          0             4
# 6                Greece             30.7%          1             9
# 7                 Italy             43.0%          0            16
# 8           Netherlands             25.0%          0             5
# 9                Poland             39.4%          1             7
# 10             Portugal             34.3%          0            12
# 11  Republic of Ireland             36.8%          1             6
# 12               Russia             22.5%          0             6
# 13                Spain             55.9%          0            11
# 14               Sweden             47.2%          0             7
# 15              Ukraine             21.2%          0             5

# %%
filtered_data.query('Red_Cards == 0')
# Out:
#               Team Shooting_Accuracy  Red_Cards  Yellow_Cards
# 0          Croatia             51.9%          0             9
# 1   Czech Republic             41.9%          0             7
# 2          Denmark             50.0%          0             4
# 3          England             50.0%          0             5
# 4           France             37.9%          0             6
# 5          Germany             47.8%          0             4
# 7            Italy             43.0%          0            16
# 8      Netherlands             25.0%          0             5
# 10        Portugal             34.3%          0            12
# 12          Russia             22.5%          0             6
# 13           Spain             55.9%          0            11
# 14          Sweden             47.2%          0             7
# 15         Ukraine             21.2%          0             5

# %%
info = { "Name" : ['Pooja','Vrushali'],
      "Age" : [28,29]
    }

df = pd.DataFrame(info)
print(df)
# Out:
#        Name  Age
# 0     Pooja   28
# 1  Vrushali   29

# %%
df.query('Age < 30')
# Out:
#        Name  Age
# 0     Pooja   28
# 1  Vrushali   29
